# %%
def easy_quiz():
    score = 0
    
    # Question 1
    print("Question 1: who is the current prime minister of India?")
    answer1 = input("a) KA Paul b) Rajiv Gandhi c) Narendra Modi d) Kim Your answer: ")

    if answer1 == "c":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is Narendra Modi.")
    
    # Question 2
    print("Question 2: What is the National Bird of India?")
    answer2 = input("a) Crow b) Owl  c) Peacock d) Duck Your answer: ")
    
    if answer2 == "c":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is Peacock.")

        # Question 3
    print("Question 3: What is the National Flower of India?")
    answer3 = input("a) Lotus b) Jasmine c) Rose d) Pushpa Your answer: ")
    
    if answer3 == "a":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is Lotus.")

        # Question 4
    print("Question 4: What is the National Animal of India?")
    answer4 = input("a) Dog b) Lion c) Bengal Tiger d) Cat Your answer: ")
    
    if answer4 == "c":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is Begal Tiger.")

        # Question 5
    print("Question 5: What is the capital of India?")
    answer5 = input("a) Tenali b) Amalapuram c) Delhi d) Hydrebad Your answer: ")
    
    if answer5 == "c":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is Delhi.")

        # Question 6
    print("Question 6: What is the National Game of  Indai ?")
    answer6 = input("a) Hide&seek b) 7Stones c) Cricket d) Hockey Your answer: ")
    
    if answer6 == "d":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is Hockey.")

        # Question 7
    print("Question 7: Who is the Deputy chief Minister of Andhra Pradesh?")
    answer7 = input("a) Salaman b) Prince c) Pawan Kalyan d) Jahnavi Your answer: ")
    
    if answer7 == "c":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is Pawan Kalyan.")
    
    # Question 8
    print("Question 8: How many states are in India?")
    answer8 = input("a) 108 b) 100  c) 119 d) 28 Your answer: ")
    
    if answer8 == "d":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is 28.")

        # Question 9
    print("Question 9: What is the capital of Andhra Pradesh?")
    answer9 = input("a) Tenali b) Amaravathi c) Amalapuram d) Vijaywada Your answer: ")
    
    if answer9 == "b":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is Amaravathi.")

        # Question 10
    print("Question 10: Who is the Principal of NRI Degree College?")
    answer10 = input("a) Mahesh Babu b) Lazar Babu c) sampunesh Babu d) Mohan Babu Your answer: ")
    
    if answer10== "b":
        print("Correct")
        score += 10
    else:
        print("Incorrect. The correct answer is Lazar Babu.")
    
    
    # Final score
    print(f"Your final score is: {score}/100")

# Run the quiz
easy_quiz()
# Out:
# Question 1: who is the current prime minister of India?
# Correct
# Question 2: What is the National Bird of India?
# Correct
# Question 3: What is the National Flower of India?
# Correct
# Question 4: What is the National Animal of India?
# Correct
# Question 5: What is the capital of India?
# Correct
# Question 6: What is the National Game of  Indai ?
# Incorrect. The correct answer is Hockey.
# Question 7: Who is the Deputy chief Minister of Andhra Pradesh?
# Incorrect. The correct answer is Pawan Kalyan.
# Question 8: How many states are in India?
# Incorrect. The correct answer is 28.
# Question 9: What is the capital of Andhra Pradesh?
# Incorrect. The correct answer is Amaravathi.
# Question 10: Who is the Principal of NRI Degree College?
# Correct
# Your final score is: 60/100
